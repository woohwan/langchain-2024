# %%
# model 인스턴스 생성
from langchain.llms import Bedrock
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler


llm_text = Bedrock(
  model_id="anthropic.claude-v2:1",
  region_name= 'us-east-1',
  endpoint_url=None,
  model_kwargs={
    "max_tokens_to_sample": 512,
    "temperature": 0,
    "top_k": 256,
    "top_p": 1,
    "stop_sequences": ["\n\nHuman:"],
  },
  streaming=True,
  callbacks=[StreamingStdOutCallbackHandler()]
)

# %%
# model 기본 테스트
from langchain_core.runnables import RunnablePassthrough
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# prompt = ChatPromptTemplate.from_template("대한민국의 수도는 어디입니까?")
# llm_text.invoke(prompt)
# chain = prompt | llm_text | StrOutputParser()
# chain.invoke({})

prompt = ChatPromptTemplate.from_template("{country}의 수도는 어디입니까?")

chain = (
  { "country": RunnablePassthrough()}
  | prompt
  | llm_text
  | StrOutputParser()
)

resp=chain.invoke("프랑스")
# Out:
#  프랑스의 수도는 파리입니다.

# %%
llm = llm_text

# %% [markdown]
# ### DB
# Connect to a SQLite DB.

# %%
from langchain.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///nba_roster.db", sample_rows_in_table_info=0)

def get_schema(_):
  return db.get_table_info()

def run_query(query):
  return db.run(query)

# %%
# Prompt
from langchain.prompts import ChatPromptTemplate

# Update the template based on the type of SQL Database like MySQL, Microsoft SQL Server and so on
template = """Based on the table schema below, write a SQL query that would answer the user's question:
{schema}

Question: {question}
SQL Query:"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "Given an input question, convert it to a SQL query. No pre-amble."),
        ("human", template),
    ]
)

# Chain to query
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

sql_response = (
    RunnablePassthrough.assign(schema=get_schema)
    | prompt
    | llm.bind(stop=["\nSQLResult:"])
    | StrOutputParser()
)

sql_response.invoke({"question": "What team is Klay Thompson on?"})
# Out:
#  SELECT "Team"
# FROM nba_roster
# WHERE "NAME" = 'Klay Thompson'
# ' SELECT "Team"\nFROM nba_roster\nWHERE "NAME" = \'Klay Thompson\''

# %%
# Chain to answer
template = """Based on the table schema below, question, sql query, and sql response, write a natural language response:
{schema}

Question: {question}
SQL Query: {query}
SQL Response: {response}
"""

prompt_response = ChatPromptTemplate.from_messages(
  [
    (
      "system",
      "Given an input question and SQL response, convert it to a natural language answer. No pre-amble"
    ),
    ("human", template)
  ]
)

full_chain = (
  RunnablePassthrough.assign(query=sql_response)
  | RunnablePassthrough.assign(
    schema=get_schema,
    response=lambda x: db.run(x["query"]),
  )
  | prompt_response
  | llm
)

full_chain.invoke({"question": "How many unique teams are there?"})
# Out:
#  ```sql
# SELECT COUNT(DISTINCT "Team")
# FROM nba_roster
# ```
#
# This query counts the number of distinct team names in the nba_roster table. The COUNT(DISTINCT) aggregate function returns the number of unique non-null values from the specified column. By applying it to the "Team" column, we can get the number of unique team names.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# OperationalError: near "```sql
# SELECT COUNT(DISTINCT "Team")
# FROM nba_roster
# ```": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[50], line 30
#      10 prompt_response = ChatPromptTemplate.from_messages(
#      11   [
#      12     (
#    (...)
#      17   ]
#      18 )
#      20 full_chain = (
#      21   RunnablePassthrough.assign(query=sql_response)
#      22   | RunnablePassthrough.assign(
#    (...)
#      27   | llm
#      28 )
# ---> 30 full_chain.invoke({"question": "How many unique teams are there?"})
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:1713, in RunnableSequence.invoke(self, input, config)
#    1711 try:
#    1712     for i, step in enumerate(self.steps):
# -> 1713         input = step.invoke(
#    1714             input,
#    1715             # mark each step as a child run
#    1716             patch_config(
#    1717                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1718             ),
#    1719         )
#    1720 # finish the root run
#    1721 except BaseException as e:
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/passthrough.py:408, in RunnableAssign.invoke(self, input, config, **kwargs)
#     402 def invoke(
#     403     self,
#     404     input: Dict[str, Any],
#     405     config: Optional[RunnableConfig] = None,
#     406     **kwargs: Any,
#     407 ) -> Dict[str, Any]:
# --> 408     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:955, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#     948 run_manager = callback_manager.on_chain_start(
#     949     dumpd(self),
#     950     input,
#     951     run_type=run_type,
#     952     name=config.get("run_name") or self.get_name(),
#     953 )
#     954 try:
# --> 955     output = call_func_with_variable_args(
#     956         func, input, config, run_manager, **kwargs
#     957     )
#     958 except BaseException as e:
#     959     run_manager.on_chain_error(e)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/config.py:309, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     307 if run_manager is not None and accepts_run_manager(func):
#     308     kwargs["run_manager"] = run_manager
# --> 309 return func(input, **kwargs)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/passthrough.py:395, in RunnableAssign._invoke(self, input, run_manager, config, **kwargs)
#     382 def _invoke(
#     383     self,
#     384     input: Dict[str, Any],
#    (...)
#     387     **kwargs: Any,
#     388 ) -> Dict[str, Any]:
#     389     assert isinstance(
#     390         input, dict
#     391     ), "The input to RunnablePassthrough.assign() must be a dict."
#     393     return {
#     394         **input,
# --> 395         **self.mapper.invoke(
#     396             input,
#     397             patch_config(config, callbacks=run_manager.get_child()),
#     398             **kwargs,
#     399         ),
#     400     }
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:2278, in RunnableParallel.invoke(self, input, config)
#    2265     with get_executor_for_config(config) as executor:
#    2266         futures = [
#    2267             executor.submit(
#    2268                 step.invoke,
#    (...)
#    2276             for key, step in steps.items()
#    2277         ]
# -> 2278         output = {key: future.result() for key, future in zip(steps, futures)}
#    2279 # finish the root run
#    2280 except BaseException as e:
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:2278, in <dictcomp>(.0)
#    2265     with get_executor_for_config(config) as executor:
#    2266         futures = [
#    2267             executor.submit(
#    2268                 step.invoke,
#    (...)
#    2276             for key, step in steps.items()
#    2277         ]
# -> 2278         output = {key: future.result() for key, future in zip(steps, futures)}
#    2279 # finish the root run
#    2280 except BaseException as e:
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:2936, in RunnableLambda.invoke(self, input, config, **kwargs)
#    2934 """Invoke this runnable synchronously."""
#    2935 if hasattr(self, "func"):
# -> 2936     return self._call_with_config(
#    2937         self._invoke,
#    2938         input,
#    2939         self._config(config, self.func),
#    2940         **kwargs,
#    2941     )
#    2942 else:
#    2943     raise TypeError(
#    2944         "Cannot invoke a coroutine function synchronously."
#    2945         "Use `ainvoke` instead."
#    2946     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:955, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#     948 run_manager = callback_manager.on_chain_start(
#     949     dumpd(self),
#     950     input,
#     951     run_type=run_type,
#     952     name=config.get("run_name") or self.get_name(),
#     953 )
#     954 try:
# --> 955     output = call_func_with_variable_args(
#     956         func, input, config, run_manager, **kwargs
#     957     )
#     958 except BaseException as e:
#     959     run_manager.on_chain_error(e)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/config.py:309, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     307 if run_manager is not None and accepts_run_manager(func):
#     308     kwargs["run_manager"] = run_manager
# --> 309 return func(input, **kwargs)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:2853, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    2846 def _invoke(
#    2847     self,
#    2848     input: Input,
#    (...)
#    2851     **kwargs: Any,
#    2852 ) -> Output:
# -> 2853     output = call_func_with_variable_args(
#    2854         self.func, input, config, run_manager, **kwargs
#    2855     )
#    2856     # If the output is a runnable, invoke it
#    2857     if isinstance(output, Runnable):
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/config.py:309, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     307 if run_manager is not None and accepts_run_manager(func):
#     308     kwargs["run_manager"] = run_manager
# --> 309 return func(input, **kwargs)
#
# Cell In[50], line 24, in <lambda>(x)
#       2 template = """Based on the table schema below, question, sql query, and sql response, write a natural language response:
#       3 {schema}
#       4
#    (...)
#       7 SQL Response: {response}
#       8 """
#      10 prompt_response = ChatPromptTemplate.from_messages(
#      11   [
#      12     (
#    (...)
#      17   ]
#      18 )
#      20 full_chain = (
#      21   RunnablePassthrough.assign(query=sql_response)
#      22   | RunnablePassthrough.assign(
#      23     schema=get_schema,
# ---> 24     response=lambda x: db.run(x["query"]),
#      25   )
#      26   | prompt_response
#      27   | llm
#      28 )
#      30 full_chain.invoke({"question": "How many unique teams are there?"})
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain/utilities/sql_database.py:433, in SQLDatabase.run(self, command, fetch)
#     423 def run(
#     424     self,
#     425     command: str,
#     426     fetch: Union[Literal["all"], Literal["one"]] = "all",
#     427 ) -> str:
#     428     """Execute a SQL command and return a string representing the results.
#     429
#     430     If the statement returns rows, a string of the results is returned.
#     431     If the statement returns no rows, an empty string is returned.
#     432     """
# --> 433     result = self._execute(command, fetch)
#     434     # Convert columns values to string to avoid issues with sqlalchemy
#     435     # truncating text
#     436     res = [
#     437         tuple(truncate_word(c, length=self._max_string_length) for c in r.values())
#     438         for r in result
#     439     ]
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain/utilities/sql_database.py:411, in SQLDatabase._execute(self, command, fetch)
#     409     else:  # postgresql and other compatible dialects
#     410         connection.exec_driver_sql("SET search_path TO %s", (self._schema,))
# --> 411 cursor = connection.execute(text(command))
#     412 if cursor.returns_rows:
#     413     if fetch == "all":
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:516, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     514     if TYPE_CHECKING:
#     515         assert isinstance(self, Executable)
# --> 516     return connection._execute_clauseelement(
#     517         self, distilled_params, execution_options
#     518     )
#     519 else:
#     520     raise exc.ObjectNotExecutableError(self)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) near "```sql
# SELECT COUNT(DISTINCT "Team")
# FROM nba_roster
# ```": syntax error
# [SQL:  ```sql
# SELECT COUNT(DISTINCT "Team")
# FROM nba_roster
# ```
#
# This query counts the number of distinct team names in the nba_roster table. The COUNT(DISTINCT) aggregate function returns the number of unique non-null values from the specified column. By applying it to the "Team" column, we can get the number of unique team names.]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Chat with a SQL DB

# %%
# Prompt
from langchain.memory import ConversationBufferMemory
from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder

template = """Given an input question, convert it to a SQL query only. Based on the table schema below, write a SQL query that would answer the user's question:
{schema}
"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", template),
        MessagesPlaceholder(variable_name="history"),
        ("human", "{question}"),
    ]
)

memory = ConversationBufferMemory(return_messages=True)

# Chain to query with memory
from langchain_core.runnables import RunnableLambda

sql_chain = (
    RunnablePassthrough.assign(
        schema=get_schema,
        history=RunnableLambda(lambda x: memory.load_memory_variables(x)["history"]),
    )
    | prompt
    | llm.bind(stop=["\nSQLResult:"])
    | StrOutputParser()
)


def save(input_output):
    output = {"output": input_output.pop("output")}
    memory.save_context(input_output, output)
    return output["output"]


sql_response_memory = RunnablePassthrough.assign(output=sql_chain) | save
sql_response_memory.invoke({"question": "What team is Klay Thompson on?"})
# Out:
#  SELECT "Team"
# FROM nba_roster
# WHERE "NAME" = 'Klay Thompson'
# ' SELECT "Team"\nFROM nba_roster\nWHERE "NAME" = \'Klay Thompson\''

# %%
# Chain to answer
template = """Based on the table schema below, question, sql query, and sql response, write a natural language response:
{schema}

Question: {question}
SQL Query: {query}
SQL Response: {response}"""
prompt_response = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Given an input question and SQL response, convert it to a natural language answer. No pre-amble.",
        ),
        ("human", template),
    ]
)

full_chain = (
    RunnablePassthrough.assign(query=sql_response_memory)
    | RunnablePassthrough.assign(
        schema=get_schema,
        response=lambda x: db.run(x["query"]),
    )
    | prompt_response
    | llm
)

full_chain.invoke({"question": "What is his salary?"})
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# OperationalError: near "AI": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 28
#       8 prompt_response = ChatPromptTemplate.from_messages(
#       9     [
#      10         (
#    (...)
#      15     ]
#      16 )
#      18 full_chain = (
#      19     RunnablePassthrough.assign(query=sql_response_memory)
#      20     | RunnablePassthrough.assign(
#    (...)
#      25     | llm
#      26 )
# ---> 28 full_chain.invoke({"question": "What is his salary?"})
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:1713, in RunnableSequence.invoke(self, input, config)
#    1711 try:
#    1712     for i, step in enumerate(self.steps):
# -> 1713         input = step.invoke(
#    1714             input,
#    1715             # mark each step as a child run
#    1716             patch_config(
#    1717                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1718             ),
#    1719         )
#    1720 # finish the root run
#    1721 except BaseException as e:
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/passthrough.py:408, in RunnableAssign.invoke(self, input, config, **kwargs)
#     402 def invoke(
#     403     self,
#     404     input: Dict[str, Any],
#     405     config: Optional[RunnableConfig] = None,
#     406     **kwargs: Any,
#     407 ) -> Dict[str, Any]:
# --> 408     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:955, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#     948 run_manager = callback_manager.on_chain_start(
#     949     dumpd(self),
#     950     input,
#     951     run_type=run_type,
#     952     name=config.get("run_name") or self.get_name(),
#     953 )
#     954 try:
# --> 955     output = call_func_with_variable_args(
#     956         func, input, config, run_manager, **kwargs
#     957     )
#     958 except BaseException as e:
#     959     run_manager.on_chain_error(e)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/config.py:309, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     307 if run_manager is not None and accepts_run_manager(func):
#     308     kwargs["run_manager"] = run_manager
# --> 309 return func(input, **kwargs)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/passthrough.py:395, in RunnableAssign._invoke(self, input, run_manager, config, **kwargs)
#     382 def _invoke(
#     383     self,
#     384     input: Dict[str, Any],
#    (...)
#     387     **kwargs: Any,
#     388 ) -> Dict[str, Any]:
#     389     assert isinstance(
#     390         input, dict
#     391     ), "The input to RunnablePassthrough.assign() must be a dict."
#     393     return {
#     394         **input,
# --> 395         **self.mapper.invoke(
#     396             input,
#     397             patch_config(config, callbacks=run_manager.get_child()),
#     398             **kwargs,
#     399         ),
#     400     }
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:2278, in RunnableParallel.invoke(self, input, config)
#    2265     with get_executor_for_config(config) as executor:
#    2266         futures = [
#    2267             executor.submit(
#    2268                 step.invoke,
#    (...)
#    2276             for key, step in steps.items()
#    2277         ]
# -> 2278         output = {key: future.result() for key, future in zip(steps, futures)}
#    2279 # finish the root run
#    2280 except BaseException as e:
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:2278, in <dictcomp>(.0)
#    2265     with get_executor_for_config(config) as executor:
#    2266         futures = [
#    2267             executor.submit(
#    2268                 step.invoke,
#    (...)
#    2276             for key, step in steps.items()
#    2277         ]
# -> 2278         output = {key: future.result() for key, future in zip(steps, futures)}
#    2279 # finish the root run
#    2280 except BaseException as e:
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:2936, in RunnableLambda.invoke(self, input, config, **kwargs)
#    2934 """Invoke this runnable synchronously."""
#    2935 if hasattr(self, "func"):
# -> 2936     return self._call_with_config(
#    2937         self._invoke,
#    2938         input,
#    2939         self._config(config, self.func),
#    2940         **kwargs,
#    2941     )
#    2942 else:
#    2943     raise TypeError(
#    2944         "Cannot invoke a coroutine function synchronously."
#    2945         "Use `ainvoke` instead."
#    2946     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:955, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#     948 run_manager = callback_manager.on_chain_start(
#     949     dumpd(self),
#     950     input,
#     951     run_type=run_type,
#     952     name=config.get("run_name") or self.get_name(),
#     953 )
#     954 try:
# --> 955     output = call_func_with_variable_args(
#     956         func, input, config, run_manager, **kwargs
#     957     )
#     958 except BaseException as e:
#     959     run_manager.on_chain_error(e)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/config.py:309, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     307 if run_manager is not None and accepts_run_manager(func):
#     308     kwargs["run_manager"] = run_manager
# --> 309 return func(input, **kwargs)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/base.py:2853, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    2846 def _invoke(
#    2847     self,
#    2848     input: Input,
#    (...)
#    2851     **kwargs: Any,
#    2852 ) -> Output:
# -> 2853     output = call_func_with_variable_args(
#    2854         self.func, input, config, run_manager, **kwargs
#    2855     )
#    2856     # If the output is a runnable, invoke it
#    2857     if isinstance(output, Runnable):
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain_core/runnables/config.py:309, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     307 if run_manager is not None and accepts_run_manager(func):
#     308     kwargs["run_manager"] = run_manager
# --> 309 return func(input, **kwargs)
#
# Cell In[9], line 22, in <lambda>(x)
#       2 template = """Based on the table schema below, question, sql query, and sql response, write a natural language response:
#       3 {schema}
#       4
#       5 Question: {question}
#       6 SQL Query: {query}
#       7 SQL Response: {response}"""
#       8 prompt_response = ChatPromptTemplate.from_messages(
#       9     [
#      10         (
#    (...)
#      15     ]
#      16 )
#      18 full_chain = (
#      19     RunnablePassthrough.assign(query=sql_response_memory)
#      20     | RunnablePassthrough.assign(
#      21         schema=get_schema,
# ---> 22         response=lambda x: db.run(x["query"]),
#      23     )
#      24     | prompt_response
#      25     | llm
#      26 )
#      28 full_chain.invoke({"question": "What is his salary?"})
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain/utilities/sql_database.py:433, in SQLDatabase.run(self, command, fetch)
#     423 def run(
#     424     self,
#     425     command: str,
#     426     fetch: Union[Literal["all"], Literal["one"]] = "all",
#     427 ) -> str:
#     428     """Execute a SQL command and return a string representing the results.
#     429
#     430     If the statement returns rows, a string of the results is returned.
#     431     If the statement returns no rows, an empty string is returned.
#     432     """
# --> 433     result = self._execute(command, fetch)
#     434     # Convert columns values to string to avoid issues with sqlalchemy
#     435     # truncating text
#     436     res = [
#     437         tuple(truncate_word(c, length=self._max_string_length) for c in r.values())
#     438         for r in result
#     439     ]
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/langchain/utilities/sql_database.py:411, in SQLDatabase._execute(self, command, fetch)
#     409     else:  # postgresql and other compatible dialects
#     410         connection.exec_driver_sql("SET search_path TO %s", (self._schema,))
# --> 411 cursor = connection.execute(text(command))
#     412 if cursor.returns_rows:
#     413     if fetch == "all":
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:516, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     514     if TYPE_CHECKING:
#     515         assert isinstance(self, Executable)
# --> 516     return connection._execute_clauseelement(
#     517         self, distilled_params, execution_options
#     518     )
#     519 else:
#     520     raise exc.ObjectNotExecutableError(self)
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File ~/miniconda3/envs/bedrock/lib/python3.10/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) near "AI": syntax error
# [SQL:  AI:  Sure thing! Here's the SQL query based on the provided table schema:
#
# SELECT SALARY FROM nba_roster WHERE NAME = 'Klay Thompson';]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
